# %%
from matplotlib import pyplot as plt
from PIL import Image
import pytesseract
import argparse
import cv2
import os

# %%
# Load an color image in grayscale 
#img = cv2.imread(args["image"],0) 

img = cv2.imread("iCard_021873_1_Daba_Ayehush_H.jpg",0)

# %%
filename = "{}.png".format(os.getpid())
print(filename)

cv2.imwrite(filename, img)
# Out:
# 22416.png
# True

# %%
# Load the image using PIL (Python Imaging Library), Apply OCR, and then delete the temporary file
text = pytesseract.image_to_string(Image.open(filename))
print(text)
os.remove(filename)
# Out:
# DECEDENT ace INTERMENT NO
# DABA, AYEHUSH H (FEMALE) 68 NA
# DATE OF (NYERMENT SECTION LOT-TER-AOW  |GR/CA/AI VETERAN
# 225 ROW 2 6
# FUNERAL HOME — VAULT GR BOX #30
# LOT OWNER RELATION
# NEXT OF KIN RELATION
# ADESSE_DABA HUSBAND
#
# ADDRESS
#
# 7217 S MAY
#
# CHICAGO, IL 60617 702-292-0263
# MARKER DEALER
#
# (OSINGLE [COMPANION [) MONUMENT QOix QOour
#
# mre cranrte (1 BRONZE/GRANITE 0 VETERAN
#
# DATE SET EMAIL a
#
#
#
# LG

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Users\Rupam\OneDrive\AI\Images\tesseract.exe'

# %%
# Using Matplotlib
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
